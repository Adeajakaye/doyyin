# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'hamoyedata.csv',
#  'map1.html',
#  'MAPPING',
#  'myexercise',
#  'mynames.txt',
#  'myprogramlist',
#  'myproject',
#  'MYWEBSITE',
#  'New Text Document.txt',
#  'number.txt',
#  'python for data visualization.ipynb',
#  'pythonHandbook',
#  'Untitled.ipynb']

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv("hamoyedata.csv")

# %%
data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
mean=data.mean(0)

# %%
mean
# Out:
# utility_id_ferc1                1.186018e+02
# report_year                     2.005806e+03
# fuel_qty_burned                 2.622119e+06
# fuel_mmbtu_per_unit             8.492111e+00
# fuel_cost_per_unit_burned       2.086490e+02
# fuel_cost_per_unit_delivered    9.175704e+02
# fuel_cost_per_mmbtu             1.930435e+01
# dtype: float64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=29523, step=1)

# %%
data.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
a=data.fuel_type_code_pudl
a
# Out:
# 0        coal
# 1        coal
# 2        coal
# 3        coal
# 4         gas
#          ...
# 29518     gas
# 29519     gas
# 29520     gas
# 29521    coal
# 29522     gas
# Name: fuel_type_code_pudl, Length: 29523, dtype: object

# %%
data.loc[:,("plant_name_ferc1","report_year")].min()
# Out:
# plant_name_ferc1    (1)sta98
# report_year             1994
# dtype: object

# %%
data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
data.groupby("fuel_unit")["fuel_unit"].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
data.groupby("report_year")["fuel_unit","fuel_qty_burned"].sum()
# Out:
#              fuel_qty_burned
# report_year
# 1994            3.364163e+09
# 1995            4.458192e+09
# 1996            2.768693e+09
# 1997            3.077973e+09
# 1998            3.617070e+09
# 1999            3.445345e+09
# 2000            3.394100e+09
# 2001            3.147821e+09
# 2002            2.585502e+09
# 2003            2.287121e+09
# 2004            2.124797e+09
# 2005            2.244703e+09
# 2006            2.432879e+09
# 2007            2.573119e+09
# 2008            2.513047e+09
# 2009            2.633401e+09
# 2010            3.056312e+09
# 2011            3.052052e+09
# 2012            3.414637e+09
# 2013            3.287065e+09
# 2014            3.161710e+09
# 2015            3.650763e+09
# 2016            3.818861e+09
# 2017            3.329380e+09
# 2018            3.974124e+09

# %%
data.groupby("fuel_type_code_pudl").first()
# Out:
#                                   record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_1994_12_1_0_7                 1         1994
# gas                  f1_fuel_1994_12_2_0_10                 2         1994
# nuclear               f1_fuel_1994_12_2_1_1                 2         1994
# oil                   f1_fuel_1994_12_6_0_2                 6         1994
# other                f1_fuel_1994_12_11_0_6                11         1994
# waste                 f1_fuel_1994_12_9_0_3                 9         1994
#
#                      plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                         rockport       ton        5377489.0
# gas                         chickasaw       mcf          40533.0
# nuclear              joseph m. farley       kgU           2260.0
# oil                      clinch river       bbl           6510.0
# other                      w.f. wyman       bbl          55652.0
# ...

# %%
data.fuel_type_code_pudl.unique()
# Out:
# array(['coal', 'gas', 'nuclear', 'oil', 'waste', 'other'], dtype=object)

# %%
data.duplicated().any()
# Out:
# False

# %%
data.mean()
# Out:
# utility_id_ferc1                1.186018e+02
# report_year                     2.005806e+03
# fuel_qty_burned                 2.622119e+06
# fuel_mmbtu_per_unit             8.492111e+00
# fuel_cost_per_unit_burned       2.086490e+02
# fuel_cost_per_unit_delivered    9.175704e+02
# fuel_cost_per_mmbtu             1.930435e+01
# dtype: float64

# %%
data.mean(axis="columns").head()
# Out:
# 0    7.685055e+05
# 1    1.498428e+06
# 2    4.258261e+05
# 3    5.345142e+05
# 4    6.076873e+03
# dtype: float64

# %%
data.dropna().describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29343.000000  29343.000000     2.934300e+04         29343.000000
# mean         118.507037   2005.819105     2.609171e+06             8.477481
# std           74.241226      7.019855     8.798699e+06            10.537478
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.375050e+04             1.024000
# 50%          122.000000   2006.000000     2.524640e+05             5.763072
# 75%          176.000000   2012.000000     1.424218e+06            17.000000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29343.000000                  2.934300e+04
# mean                  209.756592                  9.230343e+02
# std                  2863.194789                  6.898652e+04
# ...

# %%
data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
data.groupby("fuel_type_code_pudl").sum()
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                           988354     17133514     1.626898e+10
# gas                           1425666     23040664     5.562880e+10
# nuclear                         87851      1638430     4.462058e+09
# oil                            913137     16186028     5.089737e+08
# other                           18448       334284     4.923388e+08
# waste                           68026       884492     5.168139e+07
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                       177459.483188                 576254.381
# gas                         11737.687844                 156891.829
# nuclear                     14382.174064                4053318.428
# oil                         46887.135739                1361824.819
# other                          95.649646                   3048.394
# ...

# %%
a=pd.DataFrame(data.groupby("fuel_type_code_pudl").sum()["fuel_cost_per_unit_burned"])

# %%
a
# Out:
#                      fuel_cost_per_unit_burned
# fuel_type_code_pudl
# coal                                576254.381
# gas                                 156891.829
# nuclear                            4053318.428
# oil                                1361824.819
# other                                 3048.394
# waste                                 8607.492

# %%
data.groupby("plant_name_ferc1")["report_year","fuel_cost_per_unit_burned"].sum()
# Out:
#                      report_year  fuel_cost_per_unit_burned
# plant_name_ferc1
# (1)sta98                    1994                      3.500
# (2) scriba sta. 99          1994                     59.790
# (n) contra costa            1995                      2.180
# (n) pittsburg               1995                      2.250
# (n)(t)moss landing          1994                      2.260
# ...                          ...                        ...
# zimmer- aepgr share         4028                    187.027
# zion                        5985                      0.000
# zorn                       24008                     52.909
# zorn ct                    20134                     56.655
# zuni                       34068                    544.615
#
# [2315 rows x 2 columns]

# %%
data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
pd.Series(data.plant_name_ferc1.unique())
# Out:
# 0                   rockport
# 1       rockport total plant
# 2                     gorgas
# 3                      barry
# 4                  chickasaw
#                 ...
# 2310      rocky ford diesels
# 2311     airport - units 1&2
# 2312          airport unit 6
# 2313        wyodak - bhp 20%
# 2314         wygen 3 bhp 52%
# Length: 2315, dtype: object

# %%
data.groupby("plant_name_ferc1")["fuel_cost_per_unit_delivered"].mean()>30.0
# Out:
# plant_name_ferc1
# (1)sta98               False
# (2) scriba sta. 99     False
# (n) contra costa       False
# (n) pittsburg          False
# (n)(t)moss landing     False
#                        ...
# zimmer- aepgr share     True
# zion                   False
# zorn                   False
# zorn ct                False
# zuni                    True
# Name: fuel_cost_per_unit_delivered, Length: 2315, dtype: bool

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'hamoyedata.csv',
#  'map1.html',
#  'MAPPING',
#  'myexercise',
#  'mynames.txt',
#  'myprogramlist',
#  'myproject',
#  'MYWEBSITE',
#  'New Text Document.txt',
#  'number.txt',
#  'python for data visualization.ipynb',
#  'pythonHandbook',
#  'Untitled.ipynb']

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv("hamoyedata.csv")

# %%
data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
data.plant_name_ferc1.unique()
# Out:
# array(['rockport', 'rockport total plant', 'gorgas', ...,
#        'airport unit 6', 'wyodak - bhp 20%', 'wygen 3 bhp 52%'],
#       dtype=object)

# %%
data.fuel_unit.unique()
# Out:
# array(['ton', 'mcf', 'kgU', 'bbl', 'gramsU', nan, 'mwdth', 'mmbtu',
#        'mwhth', 'gal'], dtype=object)

# %%
data.groupby("fuel_unit")["report_year","fuel_qty_burned"].sum()
# Out:
#            report_year  fuel_qty_burned
# fuel_unit
# bbl           16052981     4.905918e+08
# gal             168643     2.897555e+07
# gramsU          928929     3.695163e+08
# kgU             220649     2.482233e+07
# mcf           22775695     5.529674e+10
# mmbtu           361069     2.456512e+09
# mwdth           190113     6.436056e+07
# mwhth           200640     2.892479e+09
# ton           17958031     1.493689e+10

# %%
data.plant_name_ferc1.max()
# Out:
# 'zuni'

# %%
data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
data.loc[data.report_year<1995, ["report_year","fuel_type_code_pudl","fuel_qty_burned"]]
# Out:
#       report_year fuel_type_code_pudl  fuel_qty_burned
# 0            1994                coal        5377489.0
# 1            1994                coal       10486945.0
# 2            1994                coal        2978683.0
# 3            1994                coal        3739484.0
# 4            1994                 gas          40533.0
# ...           ...                 ...              ...
# 1230         1994                coal         396121.0
# 1231         1994                 gas          56258.0
# 1232         1994                coal         205382.0
# 1233         1994                 gas          58828.0
# 1234         1994                 gas          92365.0
#
# [1235 rows x 3 columns]

# %%
data.skew()
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
data.kurt()
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %%
y=data.groupby("fuel_unit")["fuel_qty_burned","fuel_cost_per_unit_burned"].sum()

# %%
y
# Out:
#            fuel_qty_burned  fuel_cost_per_unit_burned
# fuel_unit
# bbl           4.905918e+08                1359538.172
# gal           2.897555e+07                    857.063
# gramsU        3.695163e+08                 138984.280
# kgU           2.482233e+07                3909732.918
# mcf           5.529674e+10                 146270.016
# mmbtu         2.456512e+09                  10952.314
# mwdth         6.436056e+07                   3655.067
# mwhth         2.892479e+09                    528.716
# ton           1.493689e+10                 584369.129

# %%
y.min()
# Out:
# fuel_qty_burned              2.482233e+07
# fuel_cost_per_unit_burned    5.287160e+02
# dtype: float64

# %%
data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
data.mean(axis="rows")
# Out:
# utility_id_ferc1                1.186018e+02
# report_year                     2.005806e+03
# fuel_qty_burned                 2.622119e+06
# fuel_mmbtu_per_unit             8.492111e+00
# fuel_cost_per_unit_burned       2.086490e+02
# fuel_cost_per_unit_delivered    9.175704e+02
# fuel_cost_per_mmbtu             1.930435e+01
# dtype: float64

# %%
chickasaw=data[data["plant_name_ferc1"]=="chickasaw"]

# %%
chickasaw
# Out:
#                    record_id  utility_id_ferc1  report_year plant_name_ferc1  \
# 4     f1_fuel_1994_12_2_0_10                 2         1994        chickasaw
# 1481  f1_fuel_1995_12_2_0_10                 2         1995        chickasaw
# 3342  f1_fuel_1996_12_2_0_10                 2         1996        chickasaw
#
#      fuel_type_code_pudl fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 4                    gas       mcf          40533.0                1.000
# 1481                 gas       mcf         263686.0                1.076
# 3342                 gas       mcf         375286.0                1.072
#
#       fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# 4                         2.770                         2.770
# 1481                      2.264                         2.264
# 3342                      3.202                         3.202
#
#       fuel_cost_per_mmbtu
# 4                    2.57
# 1481                 2.10
# 3342                 3.01

# %%
chickasaw_fuel=chickasaw["fuel_qty_burned"]*chickasaw["fuel_cost_per_unit_burned"]

# %%
chickasaw_fuel
# Out:
# 4        112276.410
# 1481     596985.104
# 3342    1201665.772
# dtype: float64

# %%
chickasaw.report_year.max()
# Out:
# 1996

# %%
df2=pd.DataFrame({"ful_cost":chickasaw_fuel,'report_year':chickasaw["report_year"]}).reset_index(drop=True)

# %%
df2
# Out:
#       ful_cost  report_year
# 0   112276.410         1994
# 1   596985.104         1995
# 2  1201665.772         1996

# %%
year=data[data["report_year"]==1995]

# %%
year.head()
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 1235   f1_fuel_1995_12_200_0_1               200         1995
# 1236   f1_fuel_1995_12_115_0_1               115         1995
# 1237   f1_fuel_1995_12_115_0_4               115         1995
# 1238   f1_fuel_1995_12_115_0_7               115         1995
# 1239  f1_fuel_1995_12_115_0_10               115         1995
#
#       plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 1235  aroostook valley               waste       ton         327060.0
# 1236            goudey                coal       ton         209497.0
# 1237         greenidge                coal       ton         267241.0
# 1238          jennison                coal       ton         123860.0
# 1239          hickling                coal       ton         235405.0
#
#       fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 1235               0.0045                      0.000
# 1236              26.6760                     40.384
# ...

# %%
year["fuel_qty_burned"].max()
# Out:
# 555894250.0

# %%
year.describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count       1201.000000       1201.0     1.201000e+03          1201.000000
# mean         110.139051       1995.0     3.712067e+06            10.644830
# std           62.848480          0.0     2.140555e+07            13.758002
# min            1.000000       1995.0     4.000000e+00             0.000006
# 25%           55.000000       1995.0     5.887500e+04             1.019020
# 50%          121.000000       1995.0     4.868120e+05             3.413000
# 75%          163.000000       1995.0     1.697176e+06            21.188000
# max          213.000000       1995.0     5.558942e+08           123.040000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                1201.000000                   1201.000000
# mean                  354.422555                     32.735269
# std                  3793.484721                    173.849821
# ...

# %%
year.kurt()
# Out:
# utility_id_ferc1                  -1.304311
# report_year                        0.000000
# fuel_qty_burned                  485.316234
# fuel_mmbtu_per_unit               20.289636
# fuel_cost_per_unit_burned        168.291817
# fuel_cost_per_unit_delivered     149.100663
# fuel_cost_per_mmbtu             1129.280746
# dtype: float64

# %%
year=data[data["report_year"]==1995]

# %%
year
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 1235   f1_fuel_1995_12_200_0_1               200         1995
# 1236   f1_fuel_1995_12_115_0_1               115         1995
# 1237   f1_fuel_1995_12_115_0_4               115         1995
# 1238   f1_fuel_1995_12_115_0_7               115         1995
# 1239  f1_fuel_1995_12_115_0_10               115         1995
# ...                        ...               ...          ...
# 2431   f1_fuel_1995_12_45_1_13                45         1995
# 2432    f1_fuel_1995_12_45_2_1                45         1995
# 2433    f1_fuel_1995_12_45_2_4                45         1995
# 2434    f1_fuel_1995_12_45_2_7                45         1995
# 2435   f1_fuel_1995_12_45_2_10                45         1995
#
#       plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 1235  aroostook valley               waste       ton         327060.0
# 1236            goudey                coal       ton         209497.0
# ...

# %%
x=pd.DataFrame(year.groupby("fuel_unit")["fuel_qty_burned","plant_name_ferc1"])

# %%
x
# Out:
# 0                    bblgramsUkgUmcfmmbtumwdthmwhthton
# 1         record_id  utility_id_ferc1  report_year ...
# dtype: object
